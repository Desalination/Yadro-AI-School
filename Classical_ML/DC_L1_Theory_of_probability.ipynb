# %% [markdown]
# 1.
#
# a) Зависимы. Пусть есть два несовместных события $A\neq\emptyset$ и $B\neq\emptyset$. Тогда $P(A|B) = 0 \neq P(A)$
#
# b) Зависимы. Возьмем $A \neq0$: $A\in\Sigma$, тогда для $\sigma$-алгебры $\overline{A} \in \Sigma$. Имеем $P(A|\overline{A}) = 0 \neq{P(A)}$
#
# c) Неоднозначно. Рассмотрим вероятность того, что точка ставится куда-либо в объединение данных двух квадратов:

# %% [markdown]
# ![квадраты.png](data:image/png;base64,...)

# %% [markdown]
# $P(A) = P(B) = \frac{x^2}{(2(x-t)+t)x} = \frac{x}{2x-t}$
#
# $P(A|B) = \frac{xt}{x^2} = \frac{t}{x}$
#
#
# При A$\neq$B (t=x) Вероятности не равны. При $x = 2, t = 1:
# P(A) = \frac{2}{3}, P(A|B) = \frac{1}{2}$

# %% [markdown]
# Теперь рассмотрим события с подкидыванием игрального кубика. Пусть одновременно подкидывают 2 кубика. вероятность того, что первый кубик показывает 2  равна $P(A) = \frac{1}{6}$, вероятность того, что второй показывает 3 равна $P(B) = \frac{1}{6}$, при этом $P(A|B)=\frac{P(AB)}{P(B)} = \frac{1/36}{1/6} = \frac{1}{6}$

# %% [markdown]
# 2. Подкидываются одновременно независимо 2 монеты.
#
#
# • A — появление герба на первой монете;
#
# • B — появление решки на первой монете;
# • C — появление герба на второй монете;
#
# • D — появление решки на второй монете;
#
# • E — появление хотя бы одного герба;
#
# • F — появление хотя бы одной решки;
#
# • G — появление одного герба и одной решки;
#
# • H — непоявление ни одного герба;
#
# • K — появление двух гербов
#
# (a) A + C = E
#
# (b) AC = K
#
# (c) EF = G
#
# (d) G + E = E
#
# (e) GE = G
#
# (f) BD = H
#
# (g) E + K =E

# %% [markdown]
# **3**. Две мишени по 20 градусов, весь круг 360 градусов. $P = \frac{40}{360} = \frac{1}{9}$

# %% [markdown]
# **4**. Решим задачу геометрически. Введем переменные x, y. x - время прибытия первого парохода, y - время прибытия второго парохода.
# Согласно условиям: $y\ge x+1$, $x \ge y+2$

# %% [markdown]
# ![ships.png](data:image/png;base64,...)

# %% [markdown]
# Вероятность равна площади закрашенной области:
# $P = \frac{23*23*1/2 + 22*22*1/2}{24^2} = \frac{1013}{1152}$

# %% [markdown]
# **5.**
#
# $P(A|1) = p1$
#
# $P(A|2) = 2p_2p_1+2p_3p_1+p_2^2 + p_1^2 = 1 -(p_3^2 + 2p_2p_3)$
#
# $P(A|3) = 3p_1p_2^2+3p_3p_2^2+3p_2p_1^2+p_3^3 + p_1^3 + p_2^3= 1 -(3p_3^2p_2)$
#
# $P(A|4) = 1$

# %% [markdown]
# **1.2**

# %% [markdown]
# **1**.
#
# $\int_{-∞}^{∞}\int_{-∞}^{∞} \frac{e^{-2|y|}}{\pi(1+x^2)} \,dx\,dy= 4\int_{-∞}^{0}\int_{-∞}^{0} \frac{e^{2y}}{\pi(1+x^2)} \,dx\,dy =$
#
# $=\frac{4}{\pi}\int_{-∞}^{0} {e^{2y}} arctan|_{-∞}^{0} \,dy = 2\int_{-∞}^{0} {e^{2y}}\,dy = e^{2y}|_{-∞}^{0} = 1$
#
# да, данная функция является плотностью распределения

# %% [markdown]
# **2.**

# %% [markdown]
# ![some_task_ksi_n.png](data:image/png;base64,...)

# %% [markdown]
# a)
#
# | $\xi$ \ $\eta$    | -1      |   0    |   1   | margin $\xi$
# | --------          | ------- | ------ | ----- | -----
# | -1        | 1/8   |  1/12  | 7/24 | 1/2
# | 1      | 1/3   |   1/6   | 0 | 1/2
# | margin $\eta$| 11/24 | 1/4 | 7/24
#
# b)
#
# $E(\xi) = 1/2 - 1/2 = 0$
#
# $E(\eta) = -11/24 + 7/24 = -1/6$
#
# $E(\xi\eta) = -1*(1/3+7/24) + 1*1/8=-15/24+1/8=-1/2$
#
# $E(\xi^2) = 1$
#
# $E(\eta^2) = 11/24 + 7/24 = 3/4$
#
# $cov(\xi,\eta) = E(\xi \eta) - E(\xi)E(\eta) = -1/2$
#
# $cov(\xi,\xi) = E(\xi^2) - E(\xi)^2 = 1$
#
# $cov(\eta,\eta) = E(\eta^2) - E(\eta)^2 = 3/4 + 1/6 = 11/12$
#
# Ковариационная матрица:
#
# | 1  | -1/2
# | -------- | -------
# | -1/2  | 11/12
#
#
# $cor(\xi,\eta) = \frac{cov(\xi,\eta)}{\sqrt{D(\xi)}\sqrt{D(\eta)}} = \frac{-1/2}{1*\sqrt{11/12}}$
#
#
#
# Корреляционная матрица:
#
#
# | 1  | -0.522
# | -------- | -------
# | -0.522  | 1
#
# c)
#
# $P(\xi = -1, \eta = -1) = 1/8$
#
# $P(\xi = -1)P(\eta = -1) = 1/2*11/24 = 11/48$
#
# $P(\xi = -1, \eta = -1) \neq P(\xi = -1)P(\eta = -1)$
#
# Имеем, что случайные величины зависимы.
#
# И в силу того, что корелляция отлична от нуля, случайные величины коррелированы.

# %% [markdown]
# 3.
#
# a)b)
#
# |$\psi_2$ \ $\psi_1$|2|3|4|5|6|7|8|margin $\psi_2$
# |-|-|-|-|-|-|-|-|-
# |1|1/16|2/16|3/16|2/16|3/16|0|1/16|12/16
# |0|0|0|0|2/16|0|2/16|0|4/16
# |margin $\psi_1$|1/16|2/16|3/16|4/16|3/16|2/16|1/16
#
#
# c)
#
# $E(\psi_1) = 2/16+6/16+12/16+20/16+18/16+14/16+8/16 = 80/16=5$
#
# $E(\psi_2) = 12/16=3/4$
#
# $E(\psi_1\psi_2) = 2/16+6/16+12/16+10/16+18/16+14/16+8/16 = 70/16$
#
# $E(\psi_1^2) = 4/16+18/16+48/16+100/16+108/16+98/16+64/16 = 440/16 = 55/2$
#
# $E(\psi_2^2) = 12/16=3/4$
#
# $cov(\psi_1,\psi_2) = E(\psi_1 \psi_2) - E(\psi_1)E(\psi_2) = 70/16 - 80*12/16^2 = 160/256=5/8$
#
# $cov(\psi_1,\psi_1) = E(\psi_1^2) - E(\psi_1)^2 = 55/2-25=2.5$
#
# $cov(\psi_2,\psi_2) = E(\psi_2^2) - E(\psi_2)^2 = 12/16-12^2/16^2 = 48/256=3/16$
#
# Ковариационная матрица:
#
#
#
# |cov|$\psi_1$     | $\psi_2$ |
# | -------- | -------|-
# |**$\psi_1$**| 2.5    | 0.625
# |**$\psi_2$**| 0.625      | 0.1875
#
# $cor(\psi_1,\psi_2) = \frac{cov(\psi_1,\psi_2)}{\sqrt{D(\psi_1)}\sqrt{D(\psi_2)}} = \frac{5/8}{\sqrt{2.5}\sqrt{0.1875}}=0.913$
#
#
#
# Корреляционная матрица:
#
# |cor|$\psi_1$     | $\psi_2$ |
# | -------- | -------|-
# |**$\psi_1$**| 1    | 0.913
# |**$\psi_2$**| 0.913     | 1

# %% [markdown]
# d)
#
# $P(\psi_1 = 2, \psi_2 = 1) = 1/16$
#
# $P(\psi_1 = 2)P(\psi_2 = 1) = 1/16*12/16 = 12/256 = 3/64$
#
# $P(\psi_1 = -1, \psi_2 = -1) \neq P(\psi_1 = -1)P(\psi_2 = -1)$
#
# Имеем, что случайные величины зависимы.
#
# И в силу того, что корелляция отлична от нуля, случайные величины коррелированы. Причем сильно. Корреляция составляет 0.913

# %% [markdown]
# **4.**
#
# $\xi\sim U_{-\pi,\pi}, \eta_1 = cos(\xi), \eta_2=sin(\xi)$
#
# a)
#
# $E(\eta_1) = \int _{-\pi}^{\pi}cos(x)\frac{1}{2\pi} \,dx = 0$
#
# $E(\eta_2) = \int _{-\pi}^{\pi}sin(x)\frac{1}{2\pi} \,dx = -\frac{1}{2\pi} cos(x)|_{-\pi}^{\pi} = 0$
#
# $E(\eta_1\eta_2) = \int _{-\pi}^{\pi}cos(x)sin(x) \,dx = \frac{1}{4\pi}\int _{-\pi}^{\pi}sin^2(x)\,dx=0$
#
# $E(\eta_1^2) = \int _{-\pi}^{\pi}cos^2(x)\frac{1}{2\pi}\,dx=\frac{1}{4\pi}\int _{-\pi}^{\pi}{cos(2x)+1} \,dx = 1/2$
#
# $E(\eta_2^2) = \int _{-\pi}^{\pi}cos^2(x)\frac{1}{2\pi}\,dx=\frac{1}{4\pi}\int _{-\pi}^{\pi}{1-cos(2x)} \,dx = 1/2$
#
# $cov(\eta_1,\eta_2) = E(\eta_1 \eta_2) - E(\eta_1)E(\eta_2) = 0$
#
# $cov(\eta_1,\eta_1) = D(\eta_1) = E(\eta_1^2) - E(\eta_1)^2 = 1/2$
#
# $cov(\eta_2,\eta_2) = D(\eta_2) = E(\eta_2^2) - E(\eta_2)^2 = 1/2$
#
# Ковариационная матрица:
#
# | 1/2    | 0
# | -------| -------
# |  0     | 1/2
#
#
# $cor(\eta_1,\eta_2) = \frac{cov(\eta_1,\eta_2)}{\sqrt{D(\eta_1)}\sqrt{D(\eta_2)}} = 0$
#
#
#
# Корреляционная матрица:
#
#
# | 1  | 0
# | -------- | -------
# | 0  | 1
#
# **b)**
# Так как $cor(\eta_1,\eta_2) = 0$, то случайные величины некоррелированы
#
# Проверим на независимость.
#
# Возьмем $B_1 = [0, \frac{1}{2}], B_2 = [0, \frac{1}{2}]$
#
# $P(\eta_1 \in B_1) = P(\xi \in [-\frac{\pi}{2}, -\frac{\pi}{3}] \cup [\frac{\pi}{3}, \frac{\pi}{2}]) = \frac{1}{2\pi}\frac{\pi}{6}*2=\frac{1}{6}$
#
# $P(\eta_2 \in B_2) = P(\xi \in [-\frac{\pi}{6}, 0] \cup [0, \frac{\pi}{6}]) = \frac{1}{2\pi}\frac{\pi}{6}*2=\frac{1}{6}$
#
# $P(\eta_1 \in B_1, \eta_2 \in B_2)=P({∅})=0$
#
# Следовательно случайные величиные зависимы.

# %% [markdown]
# **5.**
#
# $\xi \sim Exp_2$ и $\eta \sim U_{0,1}$
#
# $ζ  = ξ + η$

# %% [markdown]
# $$
# f_{\xi}(x)=\begin{cases}2 \,e^{-2 x},&x\geq 0,\\0,&x<0.\end{cases}
# $$
#
# $$
# f_{\eta}(x)=\begin{cases}1,&0\le x\le 1,\\0,&else.\end{cases}
# $$

# %% [markdown]
# $$
# f_{\zeta}(x) = \int\limits_{0}^\infty 2e^{-2t}f_{\eta}(x-t)\,dt.
# $$
#
# Перед нами полоса
# $$
# t \geq 0, \quad 0 \leq x - t \leq 1.
# $$
# В ней при $x \in [0, 1]$ выполняется $t \in [0, x]$ и
# $$
# f_\zeta(x) = \int\limits_0^x2e^{-2t}\, dt = 1 - e^{-2x}.
# $$
# Если $x > 1$, то $t \in [x-1, x]$ и
# $$
# f_\eta(x) = \int\limits_{x-1}^x2e^{-2t}\, dt = e^{-2(x-1)} - e^{-2x}
# $$
